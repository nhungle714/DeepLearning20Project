# %%
import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision

import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [5, 5]
matplotlib.rcParams['figure.dpi'] = 200

from data_helper import UnlabeledDataset, LabeledDataset
from helper import collate_fn, draw_box
# All the images are saved in image_folder
# All the labels are saved in the annotation_csv file
image_folder = 'data'
annotation_csv = 'data/annotation.csv'

transform = torchvision.transforms.ToTensor()
# the gan is modified from version https://github.com/BoyuanJiang/context_encoder_pytorch/
# also from pytorch tutorial https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

# %%
BATCH_SIZE=1

labeled_scene_index = np.arange(106, 134)
# The labeled dataset can only be retrieved by sample.
# And all the returned data are tuple of tensors, since bounding boxes may have different size
# You can choose whether the loader returns the extra_info. It is optional. You don't have to use it.
random.seed(1008)
random.shuffle(labeled_scene_index)
train_idx = labeled_scene_index[:22]
val_idx = labeled_scene_index[22:26]
test_idx = labeled_scene_index[26:]

transform = transform = torchvision.transforms.ToTensor()

train_set = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=train_idx,
                                  transform=transform,
                                  extra_info=True
                                 )

val_set = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=val_idx,
                                  transform=transform,
                                  extra_info=True
                                 )


test_set = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=test_idx,
                                  transform=transform,
                                  extra_info=True
                                 )
train_loader = torch.utils.data.DataLoader(train_set, batch_size=BATCH_SIZE, 
                                          shuffle=True, num_workers=2, 
                                          collate_fn=collate_fn)

val_loader = torch.utils.data.DataLoader(val_set, batch_size = BATCH_SIZE, 
                                         shuffle = True, num_workers=2, 
                                         collate_fn = collate_fn)

test_loader = torch.utils.data.DataLoader(test_set, batch_size = BATCH_SIZE, 
                                          shuffle = True, num_workers=2, 
                                          collate_fn = collate_fn)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import time, copy
from VPN_model import PPMBilinear, vpn_model

# %%
def dice_loss(true, preds, epsilon = 1e-4):
    #sh1, sh2 = preds.size()
    true = true.view(1, -1)
    preds = preds.view(1, -1)
    prod = torch.sum(true*preds,dim = 1)
    sum_tnp = torch.sum(true + preds, dim = 1)
    num = torch.sum(prod)
    denom = torch.sum(sum_tnp) + epsilon
    loss = 1 - 2*(num/denom)

    return torch.mean(loss)

def dice_loss2(pred,target):
    numerator = 2 * torch.sum(pred * target)
    denominator = torch.sum(pred + target)
    return 1 - (numerator + 1) / (denominator + 1)


def compute_dice(true, preds, epsilon = 1e-7):
    #sh1, sh2 = preds.size()
    true = true.view(1, -1)
    preds = preds.view(1, -1)
    
    prod = torch.sum(true*preds,dim = 1)
    sum_tnp = torch.sum(true + preds, dim = 1)
    
    num = torch.sum(prod)
    denom = torch.sum(sum_tnp) + epsilon

    return torch.mean(num/denom)

def compute_ts_road_map(road_map1, road_map2):
    tp = (road_map1 * road_map2).sum()

    return tp * 1.0 / (road_map1.sum() + road_map2.sum() - tp)

# %%
# The below defines the vae mapping for decoder
class encoder_for_vae(nn.Module):

    def __init__(self):
        super(encoder_for_vae, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(2048, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2)
        )

        self.mu_dec = nn.Linear(18432, 512)
        self.logvar_dec = nn.Linear(18432, 512)

    def forward(self, x):
        x = self.conv(x)
        x = x.view(-1, 18432)
        mu = self.mu_dec(x)
        logvar = self.logvar_dec(x)

        return mu, logvar
    
def get_upsampling_weight(in_channels, out_channels, kernel_size):
    """Make a 2D bilinear kernel suitable for upsampling"""
    factor = (kernel_size + 1) // 2
    if kernel_size % 2 == 1:
        center = factor - 1
    else:
        center = factor - 0.5
    og = np.ogrid[:kernel_size, :kernel_size]
    filt = (1 - abs(og[0] - center) / factor) * \
           (1 - abs(og[1] - center) / factor)
    weight = np.zeros((in_channels, out_channels, kernel_size, kernel_size),
                      dtype=np.float64)
    weight[range(in_channels), range(out_channels), :, :] = filt
    return torch.from_numpy(weight).float()

class _DecoderBlock(nn.Module):
    """
    Taken from https://github.com/zijundeng/pytorch-semantic-segmentation/blob/master/models/seg_net.py
    """
    def __init__(self, in_channels, out_channels, num_conv_layers, out_activation = 'relu'):
        super(_DecoderBlock, self).__init__()
        middle_channels = int(in_channels / 2)
        layers = [
            nn.ConvTranspose2d(in_channels, in_channels, kernel_size=2, stride=2),
            nn.Conv2d(in_channels, middle_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(middle_channels),
            nn.ReLU(inplace=True)
        ]
        layers += [
                      nn.Conv2d(middle_channels, middle_channels, kernel_size=3, padding=1),
                      nn.BatchNorm2d(middle_channels),
                      nn.ReLU(inplace=True),
                  ] * (num_conv_layers - 2)
        layers += [
            nn.Conv2d(middle_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True) if out_activation == 'relu' else nn.Sigmoid(),
        ]
        self.decode = nn.Sequential(*layers)

    def forward(self, x):
        return self.decode(x)
class decoder_conv(nn.Module):
    def __init__(self):
        super(decoder_conv, self).__init__()
        self.dec1 = _DecoderBlock(128, 256,2)
        self.dec2 = _DecoderBlock(256, 256,2)
        self.dec3 = _DecoderBlock(256, 256, 2)
        self.dec4 = _DecoderBlock(256, 256, 2)
        self.dec5 = _DecoderBlock(256 ,256, 2)
        self.dec6 = _DecoderBlock(256, 128, 2)
        self.conv_out = nn.Conv2d(128, 1,3 , padding=1)
        self.final_upsample = nn.Upsample((800, 800), mode='bilinear', align_corners=False)
        self.sigmoid = nn.Sigmoid()
        self._initialize_weights()
        
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.ConvTranspose2d):
                assert m.kernel_size[0] == m.kernel_size[1]
                initial_weight = get_upsampling_weight(
                    m.in_channels, m.out_channels, m.kernel_size[0])
                m.weight.data.copy_(initial_weight)
                
    def forward(self, x):
        x = x.view(-1, 128, 2, 2)
        x = self.dec1(x)
        x= self.dec2(x)
        x = self.dec3(x)
        x = self.dec4(x)
        x = self.dec5(x)
        x = self.dec6(x)
        x = self.conv_out(x)
        x = self.final_upsample(x)
        x = self.sigmoid(x)
        return x
class vae_mapping(nn.Module):
    def __init__(self):
        super(vae_mapping, self).__init__()
        
        self.feature_extractor = torchvision.models.resnet50(pretrained = False)
        self.encoder = [nn.Conv2d(1, 64, kernel_size=(7,7), stride=(2,2), padding=(3,3), 
                                 bias = False)] + list(self.feature_extractor.children())[1:-2]
        self.encoder = nn.Sequential(*self.encoder)
        self.encoder_for_vae = encoder_for_vae()
        self.decoder = decoder_conv()
        
    def reparameterize(self, is_training, mu, logvar):
        if is_training:
            std = torch.exp(0.5*logvar)
            eps = torch.randn_like(std)
            return eps.mul(std).add_(mu)
        else:
            return mu
        
    def forward(self, x, is_training, defined_mu = None):
        feature_maps = self.encoder(x)
        mu, logvar = self.encoder_for_vae(feature_maps)
        z = self.reparameterize(is_training, mu, logvar)
        
        pred_map = self.decoder(z)
        
        return pred_map, mu, logvar

# %%
vae_checkpoint = torch.load('/scratch/ht1162/DLResult/vae_pretrain_lane3.pth')
vae_model = vae_mapping()
vae_model.load_state_dict(vae_checkpoint['best_model'])
# Out:
# <All keys matched successfully>

# %%
vae_weights = copy.deepcopy(vae_model.decoder.dec6.state_dict())
decoder  =PPMBilinear(fc_dim=1024)
decoder.conv_last[1].load_state_dict(vae_weights)
# Out:
# <All keys matched successfully>

# %%
# The following defines the vae mapping for image used for pretraining
class encoder_for_vae_image(nn.Module):

    def __init__(self):
        super(encoder_for_vae_image, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1024, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2)
        )

        self.mu_dec = nn.Linear(10240, 512)
        self.logvar_dec = nn.Linear(10240, 512)

    def forward(self, x):
        x = self.conv(x)
        x = x.view(-1, 10240)
        mu = self.mu_dec(x)
        logvar = self.logvar_dec(x)

        return mu, logvar
def get_upsampling_weight(in_channels, out_channels, kernel_size):
    """Make a 2D bilinear kernel suitable for upsampling"""
    factor = (kernel_size + 1) // 2
    if kernel_size % 2 == 1:
        center = factor - 1
    else:
        center = factor - 0.5
    og = np.ogrid[:kernel_size, :kernel_size]
    filt = (1 - abs(og[0] - center) / factor) * \
           (1 - abs(og[1] - center) / factor)
    weight = np.zeros((in_channels, out_channels, kernel_size, kernel_size),
                      dtype=np.float64)
    weight[range(in_channels), range(out_channels), :, :] = filt
    return torch.from_numpy(weight).float()

class _SameDecoder(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride, num_layers, out_activation = 'relu'):
        super(_SameDecoder, self).__init__()
        layers = [
            nn.ConvTranspose2d(in_channels, in_channels, kernel_size=kernel_size, stride=stride),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        ]
        layers += [
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True) 
        ]*(num_layers-2)
        
        layers += [
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True) if out_activation == 'relu' else nn.Sigmoid(),
        ]
        self.decode = nn.Sequential(*layers)
    def forward(self, x):
        return self.decode(x)
class decoder_conv_image(nn.Module):
    def __init__(self):
        super(decoder_conv_image, self).__init__()
        self.dec1 = _SameDecoder(128, 256,kernel_size=2, stride=2, num_layers=4)
        self.dec2 = _SameDecoder(256, 256,kernel_size=3, stride=3, num_layers=4)
        self.dec3 = _SameDecoder(256, 256,kernel_size=2, stride=2, num_layers=4)
        self.dec4 = _SameDecoder(256, 256,kernel_size=2, stride=2, num_layers=2)
        self.dec5 = _SameDecoder(256, 256,kernel_size=2, stride=2, num_layers=2)
        self.dec6 = _SameDecoder(256, 256,kernel_size=2, stride=2, num_layers=2)

        self.dec7 = _SameDecoder(256, 128,kernel_size=2, stride=2, num_layers=2)
        self.conv_out = nn.Conv2d(128, 3,3 , padding=1)
        self.final_upsample = nn.Upsample((256, 306), mode='bilinear', align_corners=False)
        self.sigmoid = nn.Sigmoid()
        self._initialize_weights()
        
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.ConvTranspose2d):
                assert m.kernel_size[0] == m.kernel_size[1]
                initial_weight = get_upsampling_weight(
                    m.in_channels, m.out_channels, m.kernel_size[0])
                m.weight.data.copy_(initial_weight)
                
    def forward(self, x):
        x = x.view(-1, 128, 2, 2)
        x = self.dec1(x)
        x= self.dec2(x)
        x = self.dec3(x)
        x = self.dec4(x)
        x = self.dec5(x)
        x = self.dec6(x)
        x = self.dec7(x)
        x = self.conv_out(x)
        # print('after layers the size is', x.size())
        x = self.final_upsample(x)
        x = self.sigmoid(x)
        return x
class vae_mapping_image(nn.Module):
    def __init__(self):
        super(vae_mapping_image, self).__init__()
        
        self.feature_extractor = torchvision.models.resnet50(pretrained = False)
        self.encoder = list(self.feature_extractor.children())[:-3]
        self.encoder = nn.Sequential(*self.encoder)
        self.encoder_for_vae = encoder_for_vae_image()
        self.decoder = decoder_conv_image()
        
    def reparameterize(self, is_training, mu, logvar):
        if is_training:
            std = torch.exp(0.5*logvar)
            eps = torch.randn_like(std)
            return eps.mul(std).add_(mu)
        else:
            return mu
        
    def forward(self, x, is_training, defined_mu = None):
        feature_maps = self.encoder(x)
        mu, logvar = self.encoder_for_vae(feature_maps)
        z = self.reparameterize(is_training, mu, logvar)
        
        pred_map = self.decoder(z)
        
        return pred_map, mu, logvar

# %%
def train_eval_model(model, dataloaders,criterion, optimizer, 
                num_epochs, checkpoint, to_save, print_every=10, eval_every = 1, to_eval = False):
    
    start_time = time.time()
    if checkpoint:
        pt = torch.load(checkpoint)
        model.load_state_dict(pt['best_model'])
        optimizer.load_state_dict(pt['optimizer'])
        best_loss = pt['best_loss']
        print('loading weights')
    else: 
        best_loss = 1e10
    
    loss_dict = {'train':[], 'val':[]}
    dice_dict = {'train':[], 'val':[]}
    ts_dict = []
    
    for epoch in range(num_epochs):
        epoch_start = time.time()
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-'*10)

        if (to_eval) and (epoch%eval_every == 0):
            phases = ['train', 'val']
        else:
            phases = ['train']
            
        for phase in phases:
            # print(len(dataloaders[phase]))
            
            curr_loss = 0.0
            curr_dice = 0.0
            
            
            if phase == 'train':
                model.train()

            else:
                model.eval()
                curr_ts = 0.0
                
            for i, (data, _, roadmap, _) in enumerate(dataloaders[phase]):
                inputs = torch.stack(data).to(device)
                target = torch.stack(roadmap).to(device)
                
                optimizer.zero_grad()
                if phase == 'train':
                    with torch.set_grad_enabled(phase=='train'):
                        outputs = model(inputs)
                        loss = criterion(target.cpu(), outputs.cpu().squeeze(1))
                        loss.backward()
                        optimizer.step()
                else:
                    with torch.no_grad():
                        outputs = model(inputs)
                        loss = criterion(target.cpu(), outputs.cpu().squeeze(1))
                    
                with torch.no_grad():
                    dice_score = compute_dice(target.cpu(), outputs.cpu().squeeze(1))
                curr_loss += loss.item()
                curr_dice += dice_score
                if phase == 'val':
                    curr_ts += compute_ts_road_map(target.cpu(), outputs.cpu().squeeze(1))

            
            loss_dict[phase].append(curr_loss/len(dataloaders[phase]))
            dice_dict[phase].append(curr_dice/len(dataloaders[phase]))
            
            print('current epoch %s composite loss is %f'%(phase, curr_loss))
            print('current epoch %s dice coef is %f'%(phase, curr_dice))
            print('%sing 1 epoch takes %f min'%(phase, (time.time() - epoch_start)/60))
            
            if phase == 'val':
                ts_dict.append(curr_ts/len(dataloaders[phase]))
                print('current ts is %f'%(curr_ts/len(dataloaders[phase])))
                
                # val: after finishing 1 epoch
                if(curr_loss/len(dataloaders[phase])) < best_loss:
                    print('saving best model')
                    checkpt= {'best_model': model.state_dict(),
                                  'optimizer': optimizer.state_dict(), 
                                  'best_loss': curr_loss/len(dataloaders[phase])}
                    torch.save(checkpt, to_save)
                    best_loss = curr_loss/len(dataloaders[phase])
                                 
        if epoch %print_every == 0:
            print('printing test image')
            fig, ax = plt.subplots(5, 2, figsize=(15,30))
            test_idx = [173, 289, 441, 361, 9]
            for fig_i, i in enumerate(test_idx):
                inputs = val_set[i][0].unsqueeze(0).to(device)
                with torch.no_grad():
                    outputs = model(inputs).cpu().squeeze().detach()

                ax[fig_i, 0].imshow(val_set[i][2].cpu())

                ax[fig_i, 1].imshow((outputs>0.5).numpy())
            plt.show()
            
    print('This training takes ', time.time() - start_time)
    
    for key in list(loss_dict.keys()):
        if len(loss_dict[key]) > 0:
            fig = plt.figure()
            plt.plot(loss_dict[key])
            plt.title('%s Loss per epoch'%(key))
            plt.show()
    for key in list(dice_dict.keys()):
        if len(dice_dict[key]) > 0:
            fig = plt.figure()
            plt.plot(dice_dict[key])
            plt.title('%s Dice Score per epoch' %(key))
            plt.show()
    fig = plt.figure()
    plt.plot(ts_dict)
    plt.title('ts score for validation')
    plt.show()

    
    
    return model, loss_dict, dice_dict, ts_dict

# %%
# Out:
# <All keys matched successfully>

# %%
image, _, roadmap, extra  =iter(train_loader).next()

# %%
image = torch.stack(image).to(device)
roadmap = torch.stack(roadmap).to(device)

# %%
image = image.view([6, 3, 256, 306])

# %%
test_output = feature_extractor(image)

# %%
test_output.shape
# Out:
# torch.Size([6, 1024, 16, 20])

# %%
mini_set, _ = torch.utils.data.random_split(train_set, [5, len(train_set) - 5])
mini_val, _ = torch.utils.data.random_split(val_set, [3, len(val_set)-3])

mini_loader = torch.utils.data.DataLoader(mini_set, batch_size = BATCH_SIZE, 
                                          shuffle = True, num_workers = 2, 
                                          collate_fn = collate_fn)

mini_val_loader = torch.utils.data.DataLoader(mini_val, batch_size = BATCH_SIZE, 
                                          shuffle = True, num_workers = 2, 
                                          collate_fn = collate_fn)

# %%
mini_loaders = {'train': mini_loader, 'val': mini_val_loader}
dataloaders = {'train': train_loader, 'val': val_loader}

# %%
vae_image_checkpoint = torch.load('/scratch/ht1162/DLResult/vae_pretrain_image.pth')
vae_model_image  =vae_mapping_image()
vae_model_image.load_state_dict(vae_image_checkpoint['best_model'])
# Out:
# <All keys matched successfully>

# %%
feature_extractor = vae_model_image.encoder

# %%
feature_extractor = feature_extractor.to(device)
decoder = decoder.to(device)
for param in feature_extractor.parameters():
    param.require_grad=True
for param in decoder.parameters():
    param.require_grad=True

# %%
DIM1=16
DIM2=20
my_model = vpn_model(DIM1, DIM2, feature_extractor, decoder)
my_model = my_model.to(device)

for param in my_model.parameters():
    param.requires_grad = True


optimizer = torch.optim.Adam(my_model.parameters(), lr=1e-4)

# %%
model, loss_dict, dice_dict, ts_dict = train_eval_model(my_model, dataloaders, 
                                                        dice_loss, optimizer, 
                                                        num_epochs=40, checkpoint=None, 
                                                        to_save = '/scratch/ht1162/DLResult/image_vae_resnet50_w_vae.pth', 
                                                        print_every=10, 
                                                        eval_every = 1, to_eval = True)
# Out:
# Epoch 1/40
# ----------
# current epoch train composite loss is 939.474594
# current epoch train dice coef is 916.262878
# training 1 epoch takes 20.956890 min
# current epoch val composite loss is 182.203224
# current epoch val dice coef is 160.898438
# valing 1 epoch takes 22.264527 min
# current ts is 0.475395
# saving best model
# printing test image
# Epoch 2/40
# ----------
# current epoch train composite loss is 756.173021
# current epoch train dice coef is 1007.912781
# training 1 epoch takes 20.981324 min
# current epoch val composite loss is 183.127221
# current epoch val dice coef is 160.436371
# valing 1 epoch takes 22.296738 min
# current ts is 0.474576
# Epoch 3/40
# ----------
# current epoch train composite loss is 623.906455
# current epoch train dice coef is 1074.046631
# training 1 epoch takes 21.001730 min
# current epoch val composite loss is 163.192575
# current epoch val dice coef is 170.403717
# valing 1 epoch takes 22.306641 min
# current ts is 0.521768
# saving best model
# Epoch 4/40
# ----------
# current epoch train composite loss is 517.760033
# current epoch train dice coef is 1127.119873
# training 1 epoch takes 21.043187 min
# current epoch val composite loss is 154.410911
# current epoch val dice coef is 174.794510
# valing 1 epoch takes 22.357748 min
# current ts is 0.542064
# saving best model
# Epoch 5/40
# ----------
# current epoch train composite loss is 431.383218
# current epoch train dice coef is 1170.307861
# training 1 epoch takes 21.228457 min
# current epoch val composite loss is 144.094474
# current epoch val dice coef is 179.952652
# valing 1 epoch takes 22.552687 min
# current ts is 0.569114
# saving best model
# Epoch 6/40
# ----------
# current epoch train composite loss is 360.657000
# current epoch train dice coef is 1205.672485
# training 1 epoch takes 21.222549 min
# current epoch val composite loss is 140.363365
# current epoch val dice coef is 181.818237
# valing 1 epoch takes 22.549894 min
# current ts is 0.579088
# saving best model
# Epoch 7/40
# ----------
# current epoch train composite loss is 303.487865
# current epoch train dice coef is 1234.255615
# training 1 epoch takes 21.226759 min
# current epoch val composite loss is 135.640682
# current epoch val dice coef is 184.179703
# valing 1 epoch takes 22.547852 min
# current ts is 0.593043
# saving best model
# Epoch 8/40
# ----------
# current epoch train composite loss is 256.009415
# current epoch train dice coef is 1257.994629
# training 1 epoch takes 21.246026 min
# current epoch val composite loss is 150.131605
# current epoch val dice coef is 176.934113
# valing 1 epoch takes 22.548362 min
# current ts is 0.563418
# Epoch 9/40
# ----------
# current epoch train composite loss is 217.463674
# current epoch train dice coef is 1277.268921
# training 1 epoch takes 21.282129 min
# current epoch val composite loss is 143.112789
# current epoch val dice coef is 180.443588
# valing 1 epoch takes 22.602894 min
# current ts is 0.583937
# Epoch 10/40
# ----------
# current epoch train composite loss is 186.887582
# current epoch train dice coef is 1292.555542
# training 1 epoch takes 21.301184 min
# current epoch val composite loss is 135.891053
# current epoch val dice coef is 184.054550
# valing 1 epoch takes 22.621192 min
# current ts is 0.599858
# Epoch 11/40
# ----------
# current epoch train composite loss is 161.478360
# current epoch train dice coef is 1305.260254
# training 1 epoch takes 21.283673 min
# current epoch val composite loss is 156.336252
# current epoch val dice coef is 173.831894
# valing 1 epoch takes 22.598758 min
# current ts is 0.566084
# printing test image
# Epoch 12/40
# ----------
# current epoch train composite loss is 140.781588
# current epoch train dice coef is 1315.610107
# training 1 epoch takes 21.338390 min
# current epoch val composite loss is 130.844070
# current epoch val dice coef is 186.577942
# valing 1 epoch takes 22.671259 min
# current ts is 0.607340
# saving best model
# Epoch 13/40
# ----------
# current epoch train composite loss is 124.224690
# current epoch train dice coef is 1323.889160
# training 1 epoch takes 21.347080 min
# current epoch val composite loss is 143.228274
# current epoch val dice coef is 180.385880
# valing 1 epoch takes 22.690648 min
# current ts is 0.578547
# Epoch 14/40
# ----------
# current epoch train composite loss is 110.115283
# current epoch train dice coef is 1330.941650
# training 1 epoch takes 21.375122 min
# current epoch val composite loss is 130.043309
# current epoch val dice coef is 186.978317
# valing 1 epoch takes 22.704368 min
# current ts is 0.621138
# saving best model
# Epoch 15/40
# ----------
# current epoch train composite loss is 99.092940
# current epoch train dice coef is 1336.455933
# training 1 epoch takes 21.437517 min
# current epoch val composite loss is 141.804479
# current epoch val dice coef is 181.097702
# valing 1 epoch takes 22.776826 min
# current ts is 0.601857
# Epoch 16/40
# ----------
# current epoch train composite loss is 89.620545
# current epoch train dice coef is 1341.190308
# training 1 epoch takes 21.342676 min
# current epoch val composite loss is 136.938563
# current epoch val dice coef is 183.530701
# valing 1 epoch takes 22.672052 min
# current ts is 0.603859
# Epoch 17/40
# ----------
# current epoch train composite loss is 82.030866
# current epoch train dice coef is 1344.984375
# training 1 epoch takes 21.377230 min
# current epoch val composite loss is 112.811059
# current epoch val dice coef is 195.594467
# valing 1 epoch takes 22.716065 min
# current ts is 0.656775
# saving best model
# Epoch 18/40
# ----------
# current epoch train composite loss is 75.505241
# current epoch train dice coef is 1348.248901
# training 1 epoch takes 21.361341 min
# current epoch val composite loss is 114.607556
# current epoch val dice coef is 194.696182
# valing 1 epoch takes 22.732799 min
# current ts is 0.655451
# Epoch 19/40
# ----------
# current epoch train composite loss is 70.580965
# current epoch train dice coef is 1350.709717
# training 1 epoch takes 21.420383 min
# current epoch val composite loss is 125.425768
# current epoch val dice coef is 189.287094
# valing 1 epoch takes 22.755247 min
# current ts is 0.624564
# Epoch 20/40
# ----------
# current epoch train composite loss is 65.787492
# current epoch train dice coef is 1353.106689
# training 1 epoch takes 21.412321 min
# current epoch val composite loss is 125.667781
# current epoch val dice coef is 189.166168
# valing 1 epoch takes 22.746778 min
# current ts is 0.636965
# Epoch 21/40
# ----------
# current epoch train composite loss is 61.869653
# current epoch train dice coef is 1355.064453
# training 1 epoch takes 21.401069 min
# current epoch val composite loss is 136.252277
# current epoch val dice coef is 183.873978
# valing 1 epoch takes 22.738441 min
# current ts is 0.607075
# printing test image
# Epoch 22/40
# ----------
# current epoch train composite loss is 59.094807
# current epoch train dice coef is 1356.452515
# training 1 epoch takes 21.432999 min
# current epoch val composite loss is 112.994859
# current epoch val dice coef is 195.502487
# valing 1 epoch takes 22.762528 min
# current ts is 0.657774
# Epoch 23/40
# ----------
# current epoch train composite loss is 55.817099
# current epoch train dice coef is 1358.091553
# training 1 epoch takes 21.352547 min
# current epoch val composite loss is 122.892366
# current epoch val dice coef is 190.553864
# valing 1 epoch takes 22.700635 min
# current ts is 0.628861
# Epoch 24/40
# ----------
# current epoch train composite loss is 53.629541
# current epoch train dice coef is 1359.187256
# training 1 epoch takes 21.329767 min
# current epoch val composite loss is 137.584761
# current epoch val dice coef is 183.207626
# valing 1 epoch takes 22.667244 min
# current ts is 0.612029
# Epoch 25/40
# ----------
# current epoch train composite loss is 51.430457
# current epoch train dice coef is 1360.284180
# training 1 epoch takes 21.398716 min
# current epoch val composite loss is 128.004044
# current epoch val dice coef is 187.997971
# valing 1 epoch takes 22.760740 min
# current ts is 0.634353
# Epoch 26/40
# ----------
# current epoch train composite loss is 49.211266
# current epoch train dice coef is 1361.395020
# training 1 epoch takes 21.395260 min
# current epoch val composite loss is 153.042216
# current epoch val dice coef is 175.478928
# valing 1 epoch takes 22.733407 min
# current ts is 0.593867
# Epoch 27/40
# ----------
# current epoch train composite loss is 47.896269
# current epoch train dice coef is 1362.051758
# training 1 epoch takes 21.358237 min
# current epoch val composite loss is 121.227171
# current epoch val dice coef is 191.386444
# valing 1 epoch takes 22.695305 min
# current ts is 0.633288
# Epoch 28/40
# ----------
# current epoch train composite loss is 46.513020
# current epoch train dice coef is 1362.743286
# training 1 epoch takes 21.430799 min
# current epoch val composite loss is 128.088628
# current epoch val dice coef is 187.955704
# valing 1 epoch takes 22.767553 min
# current ts is 0.630165
# Epoch 29/40
# ----------
# current epoch train composite loss is 45.187186
# current epoch train dice coef is 1363.407104
# training 1 epoch takes 21.421252 min
# current epoch val composite loss is 121.287700
# current epoch val dice coef is 191.356140
# valing 1 epoch takes 22.763135 min
# current ts is 0.645206
# Epoch 30/40
# ----------
# current epoch train composite loss is 43.855927
# current epoch train dice coef is 1364.069824
# training 1 epoch takes 21.398717 min
# current epoch val composite loss is 132.928924
# current epoch val dice coef is 185.535477
# valing 1 epoch takes 22.740861 min
# current ts is 0.624016
# Epoch 31/40
# ----------
# current epoch train composite loss is 42.966592
# current epoch train dice coef is 1364.515137
# training 1 epoch takes 21.366884 min
# current epoch val composite loss is 110.664035
# current epoch val dice coef is 196.668015
# valing 1 epoch takes 22.701200 min
# current ts is 0.669658
# saving best model
# printing test image
# Epoch 32/40
# ----------
# current epoch train composite loss is 41.680743
# current epoch train dice coef is 1365.159790
# training 1 epoch takes 21.346725 min
# current epoch val composite loss is 119.358876
# current epoch val dice coef is 192.320633
# valing 1 epoch takes 22.683815 min
# current ts is 0.647672
# Epoch 33/40
# ----------
# current epoch train composite loss is 40.837519
# current epoch train dice coef is 1365.582275
# training 1 epoch takes 21.384123 min
# current epoch val composite loss is 111.308573
# current epoch val dice coef is 196.345764
# valing 1 epoch takes 22.725051 min
# current ts is 0.661612
# Epoch 34/40
# ----------
# current epoch train composite loss is 40.022277
# current epoch train dice coef is 1365.989380
# training 1 epoch takes 21.413529 min
# current epoch val composite loss is 108.929504
# current epoch val dice coef is 197.535263
# valing 1 epoch takes 22.746278 min
# current ts is 0.663458
# saving best model
# Epoch 35/40
# ----------
# current epoch train composite loss is 39.042273
# current epoch train dice coef is 1366.479614
# training 1 epoch takes 21.300602 min
# current epoch val composite loss is 163.198212
# current epoch val dice coef is 170.400970
# valing 1 epoch takes 22.644202 min
# current ts is 0.575017
# Epoch 36/40
# ----------
# current epoch train composite loss is 38.475235
# current epoch train dice coef is 1366.762207
# training 1 epoch takes 21.408924 min
# current epoch val composite loss is 117.405804
# current epoch val dice coef is 193.297180
# valing 1 epoch takes 22.750513 min
# current ts is 0.655563
# Epoch 37/40
# ----------
# current epoch train composite loss is 37.515874
# current epoch train dice coef is 1367.241333
# training 1 epoch takes 21.391761 min
# current epoch val composite loss is 114.376825
# current epoch val dice coef is 194.811508
# valing 1 epoch takes 22.736825 min
# current ts is 0.662807
# Epoch 38/40
# ----------
# current epoch train composite loss is 36.870512
# current epoch train dice coef is 1367.563721
# training 1 epoch takes 21.480029 min
# current epoch val composite loss is 134.475302
# current epoch val dice coef is 184.762299
# valing 1 epoch takes 22.827875 min
# current ts is 0.624629
# Epoch 39/40
# ----------
# current epoch train composite loss is 35.939243
# current epoch train dice coef is 1368.029785
# training 1 epoch takes 21.361165 min
# current epoch val composite loss is 106.895865
# current epoch val dice coef is 198.552017
# valing 1 epoch takes 22.691614 min
# current ts is 0.675545
# saving best model
# Epoch 40/40
# ----------
# current epoch train composite loss is 35.774177
# current epoch train dice coef is 1368.112793
# training 1 epoch takes 21.365316 min
# current epoch val composite loss is 135.508313
# current epoch val dice coef is 184.245911
# valing 1 epoch takes 22.724185 min
# current ts is 0.621695
# This training takes  54406.43217754364

# %%
model, loss_dict, dice_dict, ts_dict = train_eval_model(my_model, dataloaders, 
                                                        dice_loss, optimizer, 
                                                        num_epochs=20, checkpoint='/scratch/ht1162/DLResult/image_vae_resnet50_w_vae.pth', 
                                                        to_save = '/scratch/ht1162/DLResult/image_vae_resnet50_w_vae.pth', 
                                                        print_every=10, 
                                                        eval_every = 1, to_eval = True)
# Out:
# loading weights
# Epoch 1/20
# ----------
# current epoch train composite loss is 35.587845
# current epoch train dice coef is 1368.206421
# training 1 epoch takes 21.294525 min
# current epoch val composite loss is 105.189830
# current epoch val dice coef is 199.405167
# valing 1 epoch takes 22.630292 min
# current ts is 0.680610
# saving best model
# printing test image
# Epoch 2/20
# ----------
# current epoch train composite loss is 34.872131
# current epoch train dice coef is 1368.565308
# training 1 epoch takes 21.295018 min
# current epoch val composite loss is 144.651391
# current epoch val dice coef is 179.674271
# valing 1 epoch takes 22.626524 min
# current ts is 0.607651
# Epoch 3/20
# ----------
# current epoch train composite loss is 34.715885
# current epoch train dice coef is 1368.640259
# training 1 epoch takes 21.447066 min
# current epoch val composite loss is 139.396753
# current epoch val dice coef is 182.301575
# valing 1 epoch takes 22.968007 min
# current ts is 0.615265
# Epoch 4/20
# ----------
# current epoch train composite loss is 33.985382
# current epoch train dice coef is 1369.008179
# training 1 epoch takes 21.646459 min
# current epoch val composite loss is 107.277969
# current epoch val dice coef is 198.361160
# valing 1 epoch takes 23.194485 min
# current ts is 0.673857
# Epoch 5/20
# ----------
# current epoch train composite loss is 33.484515
# current epoch train dice coef is 1369.257690
# training 1 epoch takes 21.580245 min
# current epoch val composite loss is 102.469263
# current epoch val dice coef is 200.765335
# valing 1 epoch takes 22.920238 min
# current ts is 0.689495
# saving best model
# Epoch 6/20
# ----------
# current epoch train composite loss is 33.020851
# current epoch train dice coef is 1369.489746
# training 1 epoch takes 21.371413 min
# current epoch val composite loss is 123.111561
# current epoch val dice coef is 190.444168
# valing 1 epoch takes 22.707534 min
# current ts is 0.646078
# Epoch 7/20
# ----------
# current epoch train composite loss is 32.733978
# current epoch train dice coef is 1369.635010
# training 1 epoch takes 21.351702 min
# current epoch val composite loss is 120.739200
# current epoch val dice coef is 191.630325
# valing 1 epoch takes 22.694667 min
# current ts is 0.647840
# Epoch 8/20
# ----------
# current epoch train composite loss is 32.110141
# current epoch train dice coef is 1369.946045
# training 1 epoch takes 21.321074 min
# current epoch val composite loss is 121.563705
# current epoch val dice coef is 191.218048
# valing 1 epoch takes 22.655034 min
# current ts is 0.649624
# Epoch 9/20
# ----------
# current epoch train composite loss is 32.001582
# current epoch train dice coef is 1369.997314
# training 1 epoch takes 21.333984 min
# current epoch val composite loss is 117.433300
# current epoch val dice coef is 193.283310
# valing 1 epoch takes 22.661270 min
# current ts is 0.654864
# Epoch 10/20
# ----------
# current epoch train composite loss is 31.556938
# current epoch train dice coef is 1370.220093
# training 1 epoch takes 21.367322 min
# current epoch val composite loss is 102.918985
# current epoch val dice coef is 200.540604
# valing 1 epoch takes 22.726943 min
# current ts is 0.683185
# Epoch 11/20
# ----------
# current epoch train composite loss is 31.257439
# current epoch train dice coef is 1370.373169
# training 1 epoch takes 21.395532 min
# current epoch val composite loss is 109.790300
# current epoch val dice coef is 197.104904
# valing 1 epoch takes 22.735172 min
# current ts is 0.671043
# printing test image
# Epoch 12/20
# ----------
# current epoch train composite loss is 30.838393
# current epoch train dice coef is 1370.579468
# training 1 epoch takes 21.407102 min
# current epoch val composite loss is 112.460804
# current epoch val dice coef is 195.769592
# valing 1 epoch takes 22.734516 min
# current ts is 0.666548
# Epoch 13/20
# ----------
# current epoch train composite loss is 30.403653
# current epoch train dice coef is 1370.797363
# training 1 epoch takes 21.290270 min
# current epoch val composite loss is 124.736544
# current epoch val dice coef is 189.631638
# valing 1 epoch takes 22.679662 min
# current ts is 0.640861
# Epoch 14/20
# ----------
# current epoch train composite loss is 30.523886
# current epoch train dice coef is 1370.738647
# training 1 epoch takes 21.332468 min
# current epoch val composite loss is 99.977597
# current epoch val dice coef is 202.011200
# valing 1 epoch takes 22.664630 min
# current ts is 0.692784
# saving best model
# Epoch 15/20
# ----------
